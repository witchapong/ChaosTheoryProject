# %% [markdown]
# ## Import libs and data

# %%
import pandas as pd
import re
pd.options.display.max_columns = 999
pd.options.display.max_rows = 999
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from tqdm import tqdm
tqdm.pandas()
import pickle
import datetime
from tqdm import tqdm_notebook

# %%
df_post = pd.read_csv('../out/aviation/df_post.csv')

# %%
with open('../out/aviation/tokens_post.txt', 'rb') as fp:   #Pickling
    tokens_post = pickle.load(fp)

# %% [markdown]
# ## Calculate sentiment score and clean

# %%
pos_txt = list(pd.read_csv('../src/positive-sentiment-words.txt',header=None)[0].values)
neg_txt = list(pd.read_csv('../src/negative-sentiment-words.txt', header=None)[0].values)

# %%
print('total pos word: ',len(pos_txt))
print('total neg word: ',len(neg_txt))
# Out:
# total pos word:  512
# total neg word:  1218

# %%
pos_score_list = []
neg_score_list = []
for w_list in tqdm_notebook(tokens_post):
    pos_score=0
    neg_score=0
    for w in w_list:
        if w in pos_txt:pos_score+=1
        if w in neg_txt:neg_score+=1
    pos_score_list.append(pos_score)
    neg_score_list.append(neg_score)
    
df_post['pos_score'] = pos_score_list
df_post['neg_score'] = neg_score_list
df_post['sent_score'] = df_post.pos_score - df_post.neg_score
# Out:
# HBox(children=(IntProgress(value=0, max=54844), HTML(value='')))

# %%
df_post['sent_score'].describe()
# Out:
# count    54844.000000
# mean         0.461454
# std          3.012587
# min        -50.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max         46.000000
# Name: sent_score, dtype: float64

# %%
_ = df_post.sent_score.hist()

# %%
df_post['sentiment'] = df_post.sent_score.apply(lambda x:'positive' if x>0 else 'negative' if x<0 else 'neutral')

# %%
df_post['post_date'] = pd.to_datetime(df_post['post_date'])

# %% [markdown]
# ## Input to program
# 1) Key words<br>
# 2) As of date<br>
# 3) Window length<br>

# %%
# IDEA: -> add useful statistic like lift for keywords co-occurence
# analyse keyword x tags
# use word vector to explore neighbor words

# %% [markdown]
# ## Base sentiment query

# %%
kws = ['การบินไทย','tg']
dt = datetime.date(2018,11,1)
win_len = 365

idxs=[]
for i,tkn in enumerate(tokens_post):
    for kw in kws:
        if kw in tkn:
            idxs.append(i)
            break

df_temp = df_post.copy()
df_temp = df_temp.iloc[idxs]
print('Total posts:',len(df_temp))
# filter by datetime
df_temp = df_temp.loc[(df_temp.post_date < dt)&\
                      (dt - df_temp.post_date.dt.date < datetime.timedelta(days=win_len))]
print('Total mentions:',len(df_temp),'\n')
_=df_temp.sentiment.value_counts().plot('barh')
plt.show()
_=df_temp['sent_score'].hist()
plt.show()
# show top 5 positive and negative posts
for row in df_temp.sort_values('sent_score',ascending=False).head(5)[['title-content','sent_score']].iterrows():
    print('sentiment score:' + str(row[1]['sent_score'] )+ '\n' + row[1]['title-content']+'\n')

print('##############################################################################################################')

for row in df_temp.sort_values('sent_score',ascending=True).head(5)[['title-content','sent_score']].iterrows():
    print('sentiment score:' + str(row[1]['sent_score'] )+ '\n' + row[1]['title-content']+'\n')
# Out:
# Total posts: 1722
# Total mentions: 203
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#
่วันนี้บนเครื่องอร่อยมาก ในเล้าจน์ยังเหมือนเดิม ข้าวมันไก่ไม่ฉุ่มช่ำ แห้งเหมือนเดิม ที่อร่อยคือข้าวต้มมัดอยากให้กำลังใจการบินไทย ให้พัฒนาแบบนี้ไปอีกนานๆ ค่ะ ด้านบริการเราไม่ติ เพราะประทับใจดีอยู่แล้ว แต่พออาหารอร่อยมันรู้สึกฟินขึ้นมาทันที ปรกติไปต่างประเทศก็อร่อย แต่ในประเทศทีไร จืดและซ้ำๆ ทุกที แต่วันนี้แจ่มมากค่ะ อยากได้สูตรฉู่ฉี่ปลา หาได้ที่ไหน ติดปากมากค่ะ ขอชมเลยขาไปไม่ได้ถ่ายรูปไว้นะคะ เพราะมีคนที่ไปด้วยให้ต้องเทคแคร์เยอะ ส่วนขากลับ ขออภัย สลิ่มมาทีหลัง ติดจานข้าวที่ทานหมดแล้วไม่น่ามองก็เลยไม่ลงรูปนะคะ ส่วนมากชอบถ่ายเป็นวีดีโอค่ะ แบบซูมๆ เข้าไปเวลาที่เจอของอร่อยๆ
#
# sentiment score:22
# tabihabitto: บินน้องไทยสไมล์ WE 266 HDY-BKK แถมพาชมเครื่องบินที่ BKK By: tabihabittoSpoil คลิกเพื่อดูข้อความที่ซ่อนไว้ติดตามกันได้ทางhttps://www.facebook.com/tabihabitto/นะครับสวัสดีครับ เพื่อนๆ ชาว hflight วันนี้ผมจะมารีวิวสายการบิน Thai Smile ในเส้นทางหาดใหญ่ – สุวรรณภูมิ ครับ โดยส่วนมากเวลาเดินทาง ผมจะใช้บริการสายการบิน Low-cost เป็นหลัก (ก็อย่างว่านะครับ ราคาถูกกว่า Full service) แต่วันนี้หลังจากเดินทางกลับไปเยี่ยมบ้านในช่วงปีใหม่ ขากลับมากรุงเทพฯ หลังจากเช็คราคาของสายการบินทั้งสี่ที่ให้บริการในเส้นทางนี้ (Thai Smile, Nok Air, Thai Lion Air และ Thai Air Asia) ก็พบว่าน้องไทยยิ้มเคาะราคามาถูกที่สุด เพียงแค่ 1050 บาทเท่านั้น รวมทุกอย่างเรียบร้อยแล้ว เลยตัดสินใจใช้บริการครับเริ่มต้นก็ขอตัดภาพมาที่โถงผู้โดยสารขาออกที่สนามบินหาดใหญ่กันเลย ช่วงบ่ายๆ ผู้โดยสารค่อนข้างแน่นเลยครับสำหรับผู้โดยสารที่โดยสารในชั้น Smile Plus ก็สามารถมาใช้บริการห้องรับรอง Royal Orchid Lounge ได้ครับอยู่ริมขวาสุด ติดกับร้านไอศกรีม Dairy Queen เลยครับนั่งรออยู่ไม่นาน น้องไทยยิ้มที่เดินทางจากสุวรรณภูมิก็เดินทางมาถึงหาดใหญ่เพื่อเตรียมตัวรับเรากลับละครับวันนี้หวยมาออกที่ประตูทางออกหมายเลข 2 ครับ เครื่องบินของเราก็เข้าไปจอดเทียบเกทเป็นที่เรียบร้อย ตอนนี้พนักงานภาคพื้นดินก็เริ่มมาประจำที่เกทเพื่อเตรียม Boarding ผู้โดยสารขึ้นเครื่องละครับFlight InformationA
พอไปถึงสถานีพญาไทต่อด้วย Airport Rail Link ไปสนามบินสุวรรณภูมิ ระหว่างที่นั่งไปนั้น สืบค้นกูรูในอินเทอร์เน็ตว่าระยะเวลาเดินทางไปสนามบินสุวรรณภูมิ สรุปเวลาที่สรุปรวม 45 นาที ดูนาฬิกาข้อมือแล้วถึงสุวรรณภูมิ 07.55-08.00 น. ดังนั้นมีเวลาออกจากตัวขบวนรถไปยังเค้าเตอร์เช็คอินการบินไทยประมาณ 5-10 นาที คิดในใจว่าตกเครื่องก็ตกวุ้ยยยยยย สรุปถึงสถานีสุดท้ายรีบเดินไปประตูแรกหัวขบวน ประตูเปิดปุ๊บจ้ำอ้าว+วิ่งหน้าตั้ง ไปที่ชั้น 4 โซน Cไปถึงไม่ได้ดูเวลา ไปยืนหอบและยื่นบัตรประชาชนให้พนักงานและบอกว่าไปภูเก็ตพนักงานถามกลับมาว่าไปเที่ยวบินกี่โมง ตอบไปว่าเก้าโมงประมาณนี้ เพราะจำเวลาแน่นอนไม่ได้พนักงานก็ยื่นบัตรโดยสารและบอกว่าวันนี้ไม่ได้บัสเกตค่ะ ผมก็ งงๆ เพิ่งรู้ทีหลังว่าเที่ยวบินนี้เป็นเที่ยวบินอินเตอร์สรุปไม่ตกเครื่อง ทันโหลดกระเป่าพอดี แต่ก็เช็คอินมาก่อนล่วงหน้าแล้ว แล้วเดินไปยังประตูทางออกที่ระบุบนบัตรโดยสาร ระหว่างเดินไปนั้น ค่าที่เราคู่ควรแวะดื่มน้ำฟรี แก้กระหาย วิ่งจนหอบ คอแห้ง ณ ตรงนี้แล้วเดินต่อไปยังประตูทางออก นั่งรอประมาณ 10 นาที พนักงานก็เรียกขึ้นเครื่อง ผมรอจนเกือบคนสุดท้ายเพราะไม่ชอบการที่ต้องไปยืนรอเพื่อนนักเดินทางเอาสัมภาระไว้บนช่องเก็บสัมภาระ เป็นไปตามคิด เข้าเครื่องเกือบท้ายๆไม่ต้องมีใครขัดขวางทางเดิน เดินรวดเดียวไปท้ายเครื่อง ครั้งนี้ยังไงตั้งใจจะนั่งท้ายเครื่องที่มีที่นั่งคู่ และเป็นคู่สุดท้ายเท่านั้นนั่งไม่ทันก้นอุ่นเลย ได้ยินคำว่า "โหลดผู้โดยสารสมบูรณ์" แล้วก็เริ่มเปิดสาธิตความปลอดภัยผ่านมอนิเตอร์หน้าที่นั่งแล้วก็มีรถผลักออกไปยังรันเวย์และเหินฟ้า มุ่งหน้าสู่ภูเก็ตภาพนี้ขณะเครื่องบินขึ้นพอได้ระดับเพดานบิน เริ่มให้บริการอาหาร ซึ่งตอนนั้นมีอาการหิวมากๆดูจากการแกะอาหาร ไม่ใช่อะไรนะครับ มันเหนียวและแข็งมากกล่องอาหาร 5555555555555555กินๆๆๆๆแพร๊บเดียว หมดเลย ยังไม่อิ่ม ทำไงหละทีนี้ ตีหน้าเศร้า เล่าความหิวบอก คุณแอร์ฯว่าผมไม่อิ่มอะ ขออาหารที่ลูกค้าท่านอื่นปฏิเสธมีไหม ครับ คุณแอร์ฯยิ้มและบอกว่าได้ค่ะ แล้วก็หยิบมาให้พร้อมทั้งเสริฟกาแฟร้อนให้ คราวนี้มีศิลปะในการแกะกล่องอาหารให้น่ากินละพอหมดและอิ่ม สภาพภาชนะอาหารเป็นแบบนี้นั่งอีกสักพัก มีประกาศบอกว่ากำลังลดระดับลงเข้าสู่สนามบินภูเก็ต ช่วงนี้พนักงานก็ไล่เก็บเศษและภาชนะอาหารแล้วเครื่องบินก็ร่อนลงแบบกระแทกและเบรคหัวทิ่มหัวตำ เบาๆ อาจจะเป็นเพราะรันเวย์สั้นหรือเปล่าเพราะสังเกตเห็นตอนเลี้ยวเข้าตัวอาคาร เลยไปอีกนิดก็ชายหาดทะเลแล้ว แล้วพนักงานก็ประกาศให้นักเดินทางที่จะไปต่อยังฝรั่งเศสแยกไปยังห้องรับรองและมีเวลาพัก 30 นาที แล้วจะเรียกขึ้นเครื่องอีกครั้งพอจอดยังไม่สนิทเสียงปลดเข็มขัดพรึ๊บพลั๊บ ลุกเอื้อมเปิดช่องเก็บสัมภาระ จนสจีต้องตะโกนว่า ซิด-ดาว-พลีสสสสสสสสสสสส เพราะคนที่ลุกนั้นเป็นชาวอินเดียว/ศรีลังกา หรืออะไรก็ไม่รู้หน้าตาไปโซนทางโน้นผมก็นั่งรอไปเหอะ คอมเซปเหมือนเดิมให้คนเหลือห้องโดยสารน้อยที่สุด ค่อยเดินออกจากเครื่องเพราะไม่อยากยืนรอ  รอรับกระเป๋าต่อไปแล้วเดินออกมาขึ้นรถบัสเข้าเมือง คนละ 100 บาท ต้องออกมานอกอาคาร ถ้าเป็นฝนตกคงจะลำบากน่าดูเห็นพี่ผู้ชายที่จัดคิวบอกว่ากำลังจะให้ไปจอดเทียบอาคารใหม่ที่กำลังทำอยู่**** เอาไว้แค่นี้ก่อนนะครับ เดี๋ยวพรุ่งนี้จะมาลงภาพบรรยากาศขบวนแห่เทพเจ้า และรีวิวเที่ยวบินกลับ TG224เพิ่งรู้ว่าทั้งเที่ยวบิน ไป-กลับ ภูเก็ต ครั้งนี้ เป็นเที่ยวบิน INTER ทั้งคู่ ว่าแต่ว่า ภาพบรรยากาศขบวนแห่เทพเจ้าสามารถเอาลงในนี้ได้หรือเปล่า ครับ ขอถามเพื่อนๆพี่ๆน้องๆ ในสมาชิกที่นี้ด้วยครับ ******ชื่อสินค้า:เทศกาลกินเจภูเก็ตคะแนน:CR - Consumer Review : กระทู้รีวิวนี้เป็นกระทู้ CR โดยที่เจ้าของกระทู้- จ่ายเงินซื้อเอง หรือได้รับจากคนรู้จักที่ไม่ใช่เจ้าของสินค้า เช่น เพื่อนซื้อให้- ไม่ได้รับค่าจ้างและผลประโยชน์ใดๆข้อมูลเพิ่มเติมไม่มีดูแผนที่ขนาดใหญ่ขึ้น
#
# sentiment score:-7
 สมมุติว่าในอนาคต เกิดเหตุการณ์ไม่คาดคิด หลายๆครั้งมักจะมุ่งประเด็นไปที่นักบินก่อนคะ เวลาสืบสวน เค้าจะไปเอาตารางย้อนหลังมาเป็นปี ตรวจหาfatigues หรือสาเหตุการทำงานผิดพลาดของนักบิน ถ้าบริษัทตรวจเจอว่านักบินหยวนไปนั่งที่ที่ไม่ใช่บริษัทจัดให้ อาจโดนเอาตัดสินคาดโทษได้คะ5. โดยปรกติแล้ว สายการบินที่เคยทำจะ5.1 ปิดเฟริสคลาสเคบิน ไม่ให้ใครใช้บริการเลยคะ ในกรณีที่เอาเครื่อง3คลาสมาโอเปอเรต2คลาส ป้องกันงานงอก เช่น consistency หรือ unnecessary expensesคะ เก้าอี้เฟริสคลาสนี่เเพงมากนะ* บริษัทที่เคยบินถึงขนาดออกกฏว่าห้ามผู้โดยสารอื่นเดินผ่าน เเม้กระทั่ง ตอนเข้าเครื่องเเละออกเครื่อง เพราะจะมีคนมานั่งถ่ายรูป จับนู่นจับนี่ ประตูsuite พังได้5.2 แต่ ตอนที่เคยบิน จำได้ว่า มีอยู่ครั้งนึง เครื่องปลิ้นมาก คือ... overbooked จากเอคโค่มากมายมาเป็น40ที่ ในขณะที่บิสมีบุคไม่ถึง5.บริษัทตั้งใจ* ตัดสินใจเอาเครื่อง3คลาสมาบิน เพราะจะสามารถเก็บผู้โดยกลับได้ทั้งหมด โดยที่เสียค่าใช้จ่ายน้อยสุด เเละสามารถสร้าง loyalty ทางความคิดได้เครื่องสองคลาส คอนฟิคคือ 48/386 เเต่สามคลาสคือ 8/42/376 (ตัวเลขประมาณนี้)ถ้าเอาสองคลาสมาบิน สิ่งที่บริษัทต้องคิดคือ1. ต้อง denied ผู้โดยสารในเอคโค่เพราะขายตั๋วเกิน นั่นหมายถึงการชดใช้ค่าเสียหาย ไม่ว่าจะเป็น รร หรือ เที่ยวบินในครั้งหน้า เเละครั้งนี้2. เอาผู้โดยสารจากเอคโค่ทั้งหมดขึ้น เเล้วอัพเกรดสมาชิกที่นั่งเอคโค่มานั่งบิส กรณีนี้ บริษัทจะเสียค่าpremium products มากขึ้น เเละค่าเเรงลูกเรือในbusiness ถึง4คนเเต่ถ้าเอาเครื่องสามคลาสมาบิน เเล้วเอาเก้าอี้เฟริส8ตัวมารองรับผู้โดย5คน แล้วเอาทีที่เหลือ 42+376 รับผู้โดยสารทั้งหมด ( configure ขายตั๋วเอคโค่คือ 418 ไม่ใช่376. เเล้วเอาสมาชิกทั้งหมดมานั่งที่เก้าอี้บิสก่อนเเล้วที่เหลือตามความเหมาะสม บริการ อาหารเป็นเอคโค่เหมือนเดิม ต่างเเค่เก้าอี้ หน้าที่ การแต่งตัว business flying สาเหตุคือ1. ให้สมาชิกก่อน เพราะปรกติพวกนี้มักได้อัพเกรดอยู่แล้ว เวลาไฟลท์เต็ม2. ให้โอกาสคนที่ไม่ได้เป็นสมาชิก เเต่ดูมี potentialได้ลอง สัมผัสความสะดวกสบาย เผื่อครั้งหน้าจะมีconsiderationถ้าเลือกออปชั่นนี้ บริษัทไม่มีเสียเลย มีเเต่ได้ 1บาทก ...
#
# sentiment score:-6
# สนามบินฮ่องกง จากเทอมินอล1 ไป2 ยังไงคะ? พอดีว่าบินมาจากญี่ปุ่นโดย ANA เครื่องลงเทอมินอล1แต่ว่าจะต้องต่อเครื่องเป็น TG ที่เทอมินอล2มีเวลา ชม.ครึ่งทันมั้ยคะ?ตอนนี้กำลังสับสนว่าเทอมินอล2 นี่เช็คอินเฉยๆเครื่องออกจากเทอ1 หมดปะคะ?
#
# sentiment score:-5
# แชร์ประสบการณ์แย่ๆ และข้อระวังสำหรับตั๋วแลกไมล์ การบินไทย สวัสดีค่ะจุดประสงค์ของที่มาตั้งกระทู้มี 2 เรื่องนะคะ1. ฝากเป็นข้อควรระวังสำหรับคนที่กำลังจะแลกตั๋ว ROP กับการบินไทย ถ้ามี Flight ใด Flight นึงของ Trip เป็น Thai Smile ถึงแม้จะเป็น code share TGXXXX แต่ Operate By Thai smile ก็ไม่สามารถออกตั๋วได้นะคะ ถึงแม้คุณจะได้รหัสการจองมาแล้ว แต่ออกตั๋วไม่ได้ค่ะ ขอย้ำ รายละเอียดตามข้างล่าง2. อยากจะบ่นส่วน customer support/feedback ของการบินไทย สงสัยมากเลยค่ะ ว่าเวลาเราส่ง complaint หรืออะไรเข้าไปเนี่ยเทคนิคของเค้าคือ เงียบเฉยไป รอให้ผู้โดยสารใจเย็นไปเอง ลืมไปเอง แล้วไม่ต้องรับผิดชอบอะไรรึเปล่าคะ--- รายละเอียด (ยาวนิดนึงนะคะ) ----วันที่ 6 สิงหาคม 2018 เราโทรเข้า Call Center การบินไทย เพื่อทำการจองตั๋วแลกไมล์ Route KL<-->BKK<-->Moscow  เป็นตั๋ว 1 ฉบับได้ Booking number เรียบร้อย และเจ้าหน้าที่แจ้ง ค่าธรรมเนียม ณ วันนี้ (6/8/2018) 4,180 บาท และใช้ไมล์ 70,000 ไมล์  deadline ออกตั๋วคือวันที่ 9 สิงหาคม 2018  โดย Flight จาก KL-->BKK เป็น TG2420 Operate by Thaismile นอกนั้น TG เจ้าหน้าที่ไม่ได้แจ้งว่า ตั๋วแลกไมล์ไม่สามารถแลก Thaismile ได้ แต่กังวล เรื่อง Transit time หลังจาก check แล้ว แล้วทุกอย่างโอเค -->จนถึงจุดนี้ เราเข้าใจว่าทุกอย่างไม่มีปัญหา จึงให้สามีไปจัดการขอ Visa (ไม่ใช่คนไทยค่ะ ต้องขอ Visa) และแจ้งให้ book flight เดียวกันวันที่ 8 สิงหาคม 2018 เรื่อง visa เรียบร้อย เรา Book Flight สามีทาง Internet ได้ Flight เดียวกับที่เราทำเรื่องแลกไมล์ไว้ และทำการจ่ายค่าโรงแรมที่จองไว้วันที่ 9 สิงหาคม 2018 เราโทรเข้า Call Center อีกครั้งเพื่อออกตั๋ว เจ้าหน้าที่แจ้งว่า ไม่สามารถออกตั๋วได้ เนื่องจากมีขานึงเป็น Thai Smile หลังจากนั้นเราได้ทำการขอคุยกับ Supervisor ซึ่งทาง Supervisor พยายามช่วยและเสนอ Option ต่างๆ ซึ่งอาจจะโอเคบ้าง ไม่โอเคบ้าง เช่น1. ให้โอนแต้มจากบัตรเครดิตเข้ามาเพิ่มและแลกเป็นตั๋ว 2 ฉบับ2. ให้ซื้อตั๋ว KL<-->BKK ใหม่ แลกไมล์เฉพาะ BKK<-->Moscowเราถามทาง Supervisor ไปว่า คนที่เค้าแลกไมล์เนี่ย เค้าอยากประหยัดค่าใช้จ่ายรึเปล่าคะ แต่ที่เสนอมาเนี่ย เราต้องจ่ายเพิ่มหมดเลย เราเลยบอกว่า เราบินเป็น TG ทั้งหมดก็ได้ เพื่อให้การแลกไมล์ได้ แต่ต้องไปย้ายสามีที่จองไปแล้วมาบินเที่ยวเดียวกับเราด้วย และขอโรงแรม 1 คืนที่กรุงเทพ เนื่องจาก ถ้าบิน TG ทั้งหมด จาก KL มากรุงเทพ TG ไม่มีบินเช้า ต้องบินล่วงหน้ามาก่อน 1 วัน ก็ไม่ได้อีก ไม่มีนโยบาย สรุป เราก็ยืนยันว่า เราต้องการ Flight เดิม เนื่องจากสามีได้ทำการจองเรียบร้อยแล้ว visa ยื่นแล้วระบุวันเดินทางไปกลับชัดเจน ค่าโรงแรมจ่ายแล้วและเป็น Non cancellable ทาง Supervisor ก็ขอไปปรึกษาหัวหน้าก่อน หลังจากนั้นเราได้มีการโทร check update คำตอบระหว่างวัน สรุปจบที่ไม่ได้ เราก็โกรธ โมโหจนเหนื่อย เราถามทาง Supervisor ว่า ผู้โดยสารทำอะไรผิดหรอ ทางโน้นบอกว่า เราไม่ผิด 555 หลังจากไปฟัง record ที่เราคุยกับ Call Center เค้า สรุปเด็กเค้าผิดเอง แต่จะช่วยให้เราออกตั๋วแบบที่เราอยากได้ไม่ได้ ข้อเสนอที่เราขอก็ไม่ได้ สรุป เราเหนื่อย เราเลยบอกว่า งั้นออกตั๋ว 2 ฉบับแล้วกัน เราซื้อ KL<-->BKK ส่วน BKK<-->Moscow ก็แลกไมล์เอา เพราะเราคงจะทำอะไรไม่ได้ละ ยกเลิก trip ก็ไม่ได้ คงทำได้แค่ส่ง complaint ทาง Supervisor ขอให้เราไม่ส่ง complaint โดยขอเวลาไป work โดยการบินไทย abosorb ticket KL<-->BKK ให้ส่วนเราแลกไมล์เฉพาะ BKK<-->Moscow ซึ่งเป็น Solution ที่เราพอใจ และจะให้คำตอบภายในวันที่ 14 สิงหาคมวันที่ 14 สิงหาคม 2018 เราโทรเข้า Call Center อีกครั้งเพื่อสรุปคือ ไม่สามารถทำให้ได้ ทำให้ได้เพียง compensate ด้วยไมล์ 2,000 ไมล์ และเราต้องรับผิดชอบค่าใช้จ่ายจาก KL<-->BKK เอง มาถึงจุดนี้ เราอยากทราบว่า หากคุณมาเป็นเราคุณจะรับข้อเสนอไมล์ 2,000 ไมล์นี้ไหมคะ เรารับไม่ได้ค่ะ แต่ก็ไม่มีทางเลือกที่จะต้องออกตั๋ว โดยเป็นตั๋วซื้อเอง 1 ฉบับและแลกไมล์ 1 ฉบับ ค่าใช้จ่ายทั้งสิ้นประมาณ 10,120 บาท จากเดิมประมาณ 4,180 บาท และก็ไม่มีประโยชน์ที่จะคุยกับ supervisor ต่อไปเพราะถึงแม้ว่าจะ service ดี มีความเข้าใจและเห็นอกเห็นใจผู้โดยสารแต่ก็ไม่มี Authorize ในการ approveเราก็ได้ส่งเรื่องเข้าไปร้องเรียนโดยเล่าเรื่องทั้งหมดพร้อมเรียกร้อง compensate กรอกผ่าน website การบินไทยหน้า feedback ผ่านไป 1 สัปดาห์เงียบ เราเลยส่ง email ไปที่ customer@thaiairways.com และ ROP ได้เป็น auto reply ตอบกลับมา จนถึงวันนี้ก็ยังไม่ได้มีเจ้าหน้าที่หรือใครมารับผิดชอบจนถึงจุดที่ ขอบอกเลยค่ะว่า ปลง เลยอยากจะมาแชร์ประสบการณ์ เผื่อจะมีประโยชน์ก่อนเพื่อนๆจะแลกไมล์  จุดนึงอาจจะเป็นความประมาทของเราด้วยที่ค ...

# %% [markdown]
# ## Visualize sentiment through time

# %%
# extract month-year and year from date time
df_post['month-year'] = df_post.post_date.progress_apply(lambda x:datetime.date(x.year,x.month,1))
# Out:
# 100%|██████████| 54844/54844 [00:00<00:00, 114075.65it/s]

# %%
df_post['year'] = df_post.post_date.dt.year

# %%
kws = ['การบินไทย','tg']

idxs=[]
for i,tkn in enumerate(tokens_post):
    for kw in kws:
        if kw in tkn:
            idxs.append(i)
            break

# copy and filter
df_temp = df_post.copy()
df_temp = df_temp.iloc[idxs]

# aggregate
df_temp_mo = df_temp.groupby(['month-year','sentiment'])['sent_score'].count().reset_index()
df_temp_y = df_temp.groupby(['year','sentiment'])['sent_score'].count().reset_index()

_ = sns.lineplot(x='month-year', y='sent_score', hue='sentiment',data=df_temp_mo)
plt.show()
_ = sns.lineplot(x='year', y='sent_score', hue='sentiment',data=df_temp_y)
plt.show()

# %% [markdown]
# ## sentiment by user

# %%
kws = ['การบินไทย','tg']
dt = datetime.date(2018,12,1)
win_len = 365

idxs=[]
for i,tkn in enumerate(tokens_post):
    for kw in kws:
        if kw in tkn:
            idxs.append(i)
            break

df_temp = df_post.copy()
df_temp = df_temp.iloc[idxs]
print('Total posts: ',len(df_temp))
# filter by datetime
df_temp = df_temp.loc[(df_temp.post_date < dt)&\
                      (dt - df_temp.post_date.dt.date < datetime.timedelta(days=win_len))]
print('Total mentions: ',len(df_temp))

print('Total unique user: ',df_temp.user_id.nunique())
# Out:
# Total posts:  1722
# Total mentions:  202
# Total unique user:  173
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#   app.launch_new_instance()

# %%
df_temp['user_id'] = df_temp['user_id'].astype(int)

# visualize engagement by top user
df_temp_user = df_temp.groupby('user_id')['sentiment'].count().reset_index().sort_values('sentiment',ascending=False)

df_temp_user.rename({'sentiment':'total_post'},axis=1,inplace=True)

_ = df_temp_user.head(50).plot(x='user_id',y='total_post',kind='barh',legend=False,figsize=(6,10))

# %%
# single user view
user_id = 1228757
df_temp_1u = df_temp.loc[df_temp.user_id == user_id]

_ = df_temp_1u.sentiment.value_counts().plot('barh')
